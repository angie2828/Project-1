# %%
# Import libraries and dependencies
import os
import pandas as pd
import panel as pn
import alpaca_trade_api as tradeapi
import csv
from pathlib import Path
import hvplot.pandas
import numpy as np

# %% [markdown]
# #### READING IN THE DATA

# %%
# Read in data
# SPY Full Date Range
f_spy_ss_csv = pd.read_csv(
    Path("f_spy_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# SPY First Dip
c1_spy_ss_csv = pd.read_csv(
    Path("c1_spy_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# SPY Second Dip
c2_spy_ss_csv = pd.read_csv(
    Path("c2_spy_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# SPY Third Dip
c3_spy_ss_csv = pd.read_csv(
    Path("c3_spy_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VAW Full Date Range
f_vaw_ss_csv = pd.read_csv(
    Path("f_vaw_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VAW First Dip
c1_vaw_ss_csv = pd.read_csv(
    Path("c1_vaw_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VAW Second Dip
c2_vaw_ss_csv = pd.read_csv(
    Path("c2_vaw_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VAW Third Dip
c3_vaw_ss_csv = pd.read_csv(
    Path("c3_vaw_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VCR Full Date Range
f_vcr_ss_csv = pd.read_csv(
    Path("f_vcr_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VCR First Dip
c1_vcr_ss_csv = pd.read_csv(
    Path("c1_vcr_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VCR Second Dip
c2_vcr_ss_csv = pd.read_csv(
    Path("c2_vcr_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VCR Third Dip
c3_vcr_ss_csv = pd.read_csv(
    Path("c3_vcr_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VIS Full Date Range
f_vis_ss_csv = pd.read_csv(
    Path("f_vis_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VIS First Dip
c1_vis_ss_csv = pd.read_csv(
    Path("c1_vis_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VIS Second Dip
c2_vis_ss_csv = pd.read_csv(
    Path("c2_vis_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VIS Third Dip
c3_vis_ss_csv = pd.read_csv(
    Path("c3_vis_ss_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

### Jason's CSVs:

# IYR Full Date Range
f_rem_jp = pd.read_csv(
    Path("f_rem_jp.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# IYR First Dip
c1_iyr_jp = pd.read_csv(
    Path("c1_iyr_jp.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# IYR Second Dip
c2_iyr_jp = pd.read_csv(
    Path("c2_iyr_jp.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# IYR Third Dip
c3_iyr_jp = pd.read_csv(
    Path("c3_iyr_jp.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)


# VNQ Full Date Range
f_vnq_jp = pd.read_csv(
    Path("f_vnq_jp.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VNQ First Dip
c1_vnq_jp = pd.read_csv(
    Path("c1_vnq_jp.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VNQ Second Dip
c2_vnq_jp = pd.read_csv(
    Path("c2_vnq_jp.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VNQ Third Dip
c3_vnq_jp = pd.read_csv(
    Path("c3_vnq_jp.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

### Jesus's CSVs:

# VDC Full Date Range
f_vdc_js_csv = pd.read_csv(
    Path("f_vdc_js_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VDC First Dip
c1_vdc_js_csv = pd.read_csv(
    Path("c1_vdc_js_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VDC Second Dip
c2_vdc_js_csv = pd.read_csv(
    Path("c2_vdc_js_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VDC Third Dip
c3_vdc_js_csv = pd.read_csv(
    Path("c3_vdc_js_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# XLP Full Date Range
f_xlp_js_csv = pd.read_csv(
    Path("f_xlp_js_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# XLP First Dip
c1_xlp_js_csv = pd.read_csv(
    Path("c1_xlp_js_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# XLP Second Dip
c2_xlp_js_csv = pd.read_csv(
    Path("c2_xlp_js_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# XLP Third Dip
c3_xlp_js_csv = pd.read_csv(
    Path("c3_xlp_js_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)


### Angie's CSVs:

# XLF Full Date Range
f_xlf_af = pd.read_csv(
    Path("f_xlf_af.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# XLF First Dip
c1_xlf_af = pd.read_csv(
    Path("c1_xlf_af.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# XLF Second Dip
c2_xlf_af = pd.read_csv(
    Path("c2_xlf_af.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# XLF Third Dip
c3_xlf_af = pd.read_csv(
    Path("c3_xlf_af.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)


# VHT Full Date Range
f_vht_af = pd.read_csv(
    Path("f_vht_af.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VHT First Dip
c1_vht_af = pd.read_csv(
    Path("c1_vht_af.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VHT Second Dip
c2_vht_af = pd.read_csv(
    Path("c2_vht_af.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VHT Third Dip
c3_vht_af = pd.read_csv(
    Path("c3_vht_af.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)


### Kashyap's CSVs:

# VGT Full Date Range
f_vgt_ks_csv = pd.read_csv(
    Path("f_vgt_ks_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VGT First Dip
c1_vgt_ks_csv = pd.read_csv(
    Path("c1_vgt_ks_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VGT Second Dip
c2_vgt_ks_csv = pd.read_csv(
    Path("c2_vgt_ks_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VGT Third Dip
c3_vgt_ks_csv = pd.read_csv(
    Path("c3_vht_af.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VDE Full Date Range
f_vde_ks_csv = pd.read_csv(
    Path("f_vde_ks_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VDE First Dip
c1_vde_ks_csv = pd.read_csv(
    Path("c1_vde_ks_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VDE Second Dip
c2_vde_ks_csv = pd.read_csv(
    Path("c2_vde_ks_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)

# VDE Third Dip
c3_vde_ks_csv = pd.read_csv(
    Path("c3_vde_ks_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="Date",
)


f_vis_ss_csv.shape
# Out:
# (2767, 1)

# %% [markdown]
# ## Full Date Range

# %%
# Full Date Range DF
# Create a new pivot table where the columns are the closing prices for each ticker
f_vaw_vcr_vis_spy_df = pd.concat([f_spy_ss_csv, f_vaw_ss_csv, f_vcr_ss_csv, f_vis_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
f_vaw_vcr_vis_spy_df.sort_index(inplace=True)

# Set column names
f_vaw_vcr_vis_spy_df.columns = ['SPY', 'VAW', 'VCR', 'VIS']

# Display a few rows
f_vaw_vcr_vis_spy_df.head()

# Use the `pct_change` function to calculate daily returns
f_vaw_vcr_vis_spy_daily_returns = f_vaw_vcr_vis_spy_df.pct_change().dropna()
f_vaw_vcr_vis_spy_daily_returns.head()
# Out:
#                  SPY       VAW       VCR       VIS
# Date
# 2010-01-05  0.002647  0.006011  0.006364  0.004378
# 2010-01-06  0.000704  0.014085  0.001054  0.002464
# 2010-01-07  0.004221 -0.004349  0.008633  0.012287
# 2010-01-08  0.003328  0.010850  0.000835  0.013259
# 2010-01-11  0.001397 -0.003345 -0.001252  0.009399

# %%
f_vaw_vcr_vis_spy_daily_returns.describe()
# Out:
#                SPY          VAW          VCR          VIS
# count  2766.000000  2766.000000  2766.000000  2766.000000
# mean      0.000489     0.000381     0.000709     0.000505
# std       0.010901     0.013739     0.011982     0.012943
# min      -0.109424    -0.110705    -0.130318    -0.114612
# 25%      -0.003517    -0.005987    -0.004460    -0.004907
# 50%       0.000633     0.000800     0.001261     0.000978
# 75%       0.005424     0.007167     0.006689     0.006425
# max       0.090603     0.118297     0.092098     0.119055

# %% [markdown]
# ### Analysis of above chart goes here

# %% [markdown]
# ## First Dip

# %%
# First Dip DF
# Create a new pivot table where the columns are the closing prices for each ticker
c1_vaw_vcr_vis_spy_df = pd.concat([c1_spy_ss_csv, c1_vaw_ss_csv, c1_vcr_ss_csv, c1_vis_ss_csv], axis="columns", join="inner")


# Sort datetime index in ascending order (past to present)
c1_vaw_vcr_vis_spy_df.sort_index(inplace=True)

# Set column names
c1_vaw_vcr_vis_spy_df.columns = ['SPY', 'VAW', 'VCR', 'VIS']

# Display a few rows
c1_vaw_vcr_vis_spy_df.head()

# Use the `pct_change` function to calculate daily returns
c1_vaw_vcr_vis_spy_daily_returns = c1_vaw_vcr_vis_spy_df.pct_change().dropna()
c1_vaw_vcr_vis_spy_daily_returns.head()
# Out:
#                  SPY       VAW       VCR       VIS
# Date
# 2006-01-04  0.004736  0.005899  0.000756  0.010605
# 2006-01-05  0.000628  0.001792  0.000566 -0.002580
# 2006-01-06  0.008322  0.010732  0.008303  0.008106
# 2006-01-09  0.002569  0.002091  0.009171  0.005133
# 2006-01-10  0.001010 -0.002087  0.001855  0.000170

# %%
c1_vaw_vcr_vis_spy_described = c1_vaw_vcr_vis_spy_daily_returns.describe()
c1_vaw_vcr_vis_spy_described
# Out:
#                SPY          VAW          VCR          VIS
# count  1245.000000  1245.000000  1245.000000  1245.000000
# mean      0.000118     0.000453     0.000258     0.000246
# std       0.015692     0.020429     0.017240     0.017276
# min      -0.098448    -0.123041    -0.093891    -0.093129
# 25%      -0.005373    -0.008750    -0.006967    -0.006663
# 50%       0.000593     0.001529     0.000630     0.001011
# 75%       0.006386     0.010900     0.007968     0.007933
# max       0.145198     0.108867     0.110615     0.093930

# %%
c1_vaw_vcr_vis_spy_described.columns
# Out:
# Index(['SPY', 'VAW', 'VCR', 'VIS'], dtype='object')

# %%
# STD and Mean for Grouing During First Dip
c1_spy_std = c1_vaw_vcr_vis_spy_described.loc['std','SPY']
c1_vaw_std = c1_vaw_vcr_vis_spy_described.loc['std','VAW']
c1_vcr_std = c1_vaw_vcr_vis_spy_described.loc['std','VCR']
c1_vis_std = c1_vaw_vcr_vis_spy_described.loc['std','VIS']
c1_spy_mean = c1_vaw_vcr_vis_spy_described.loc['mean','SPY']
c1_vaw_mean = c1_vaw_vcr_vis_spy_described.loc['mean','VAW']
c1_vcr_mean = c1_vaw_vcr_vis_spy_described.loc['mean','VCR']
c1_vis_mean = c1_vaw_vcr_vis_spy_described.loc['mean','VIS']

#df_shares = pd.DataFrame(shares_data, index=tickers)

# %% [markdown]
# ##### This bar chart shows the standard deviation of daily returns during the first market dip in question. Standard deviation is regarded as an indicator of volatility. Here, we see the S&P500 had the lowest volatility in the grouping, and the Materials ETF (VAW) demonstrated the highest volatility.

# %%
c1_vaw_vcr_vis_spy_mean = pd.DataFrame(columns=['SPY','VAW','VCR','VIS'])
#columns=[spy_std_first_dip,vaw_std_first_dip,vcr_std_first_dip,vis_std_first_dip]
c1_vaw_vcr_vis_spy_mean['SPY']=[c1_spy_mean]
c1_vaw_vcr_vis_spy_mean['VAW']=[c1_vaw_mean]
c1_vaw_vcr_vis_spy_mean['VCR']=[c1_vcr_mean]
c1_vaw_vcr_vis_spy_mean['VIS']=[c1_vis_mean]
c1_vaw_vcr_vis_spy_mean.head()
# Out:
#         SPY       VAW       VCR       VIS
# 0  0.000118  0.000453  0.000258  0.000246

# %%
c1_vaw_vcr_vis_spy_mean.hvplot.bar(
    title="First Dip - Mean Daily Returns of Sector Grouping - 10/01/2007 to 03/02/2009",
    xlabel="Market Sectors",
    ylabel="Mean Daily Returns - First Dip",
    yformatter='%.0f'
)
# Out:
# :Bars   [index,Variable]   (value)

# %% [markdown]
# ##### Once again, the S&P500 came out ahead vs this grouoing of ETFs during the first dip, this time in terms of their daily returns.

# %% [markdown]
# ## First Dip - Evaluate Correlation of ETF Returns

# %%
# Use the `corr` function to calculate the correlation between stock returns
c1_vaw_vcr_vis_spy_correlation = c1_vaw_vcr_vis_spy_daily_returns.corr()
c1_vaw_vcr_vis_spy_correlation
# Out:
#           SPY       VAW       VCR       VIS
# SPY  1.000000  0.880906  0.911913  0.927504
# VAW  0.880906  1.000000  0.827228  0.893969
# VCR  0.911913  0.827228  1.000000  0.921402
# VIS  0.927504  0.893969  0.921402  1.000000

# %%
import seaborn as sns

# %% [markdown]
# ## First Dip - Correlation of Daily Returns of ETFs in Grouping

# %%
# Use the `heatmap` function from the Seaborn library to visualize the correlation table
sns.heatmap(c1_vaw_vcr_vis_spy_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### It is a pretty straightforward conclusion that the ETFs in this grouping were all strongly correlated to the S&P500 during the first dip.

# %% [markdown]
# ## First Dip - Standard Deviation

# %%
# Create new dataframe with std row from descrition dataframe.
c1_vaw_vcr_vis_spy_std = pd.DataFrame(columns=['SPY','VAW','VCR','VIS'])
c1_vaw_vcr_vis_spy_std['SPY']=[c1_spy_std]
c1_vaw_vcr_vis_spy_std['VAW']=[c1_vaw_std]
c1_vaw_vcr_vis_spy_std['VCR']=[c1_vcr_std]
c1_vaw_vcr_vis_spy_std['VIS']=[c1_vis_std]
c1_vaw_vcr_vis_spy_std.head()
# Out:
#         SPY       VAW      VCR       VIS
# 0  0.015692  0.020429  0.01724  0.017276

# %%
c1_vaw_vcr_vis_spy_std.hvplot.bar(
    title="First Dip - Standard Deviation of Sector Grouping - 10/01/2007 to 03/02/2009",
    xlabel="Market Sectors",
    ylabel="Standard Deviation - First Dip"
)
# Out:
# :Bars   [index,Variable]   (value)

# %%
# Plot a rolling 30-day mean of VAW and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c1_vaw_spy_rm30 = pd.concat([c1_vaw_ss_csv, c1_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c1_vaw_spy_rm30.sort_index(inplace=True)

# Set column names
c1_vaw_spy_rm30.columns = ['VAW', 'SPY']

# Display a few rows
c1_vaw_spy_rm30.head()

c1_vaw_spy_rm30_plot = c1_vaw_spy_rm30.rolling(window=30).mean().hvplot(
    title='First Dip - Vanguard Materials Index Fund (VAW) & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VAW', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c1_vaw_spy_rm30_plot

##########

# Plot a rolling 30-day mean of VCR and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c1_vcr_spy_rm30 = pd.concat([c1_vcr_ss_csv, c1_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c1_vcr_spy_rm30.sort_index(inplace=True)

# Set column names
c1_vcr_spy_rm30.columns = ['VCR', 'SPY']

# Display a few rows
c1_vcr_spy_rm30.head()

c1_vcr_spy_rm30_plot = c1_vcr_spy_rm30.rolling(window=30).mean().hvplot(
    title='First Dip - Vanguard Consumer Discretionary Index Fund (VCR) & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VCR', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c1_vcr_spy_rm30_plot

##########

# Plot a rolling 30-day mean of VIS and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c1_vis_spy_rm30 = pd.concat([c1_vis_ss_csv, c1_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c1_vis_spy_rm30.sort_index(inplace=True)

# Set column names
c1_vis_spy_rm30.columns = ['VIS', 'SPY']

# Display a few rows
c1_vis_spy_rm30.head()

c1_vis_spy_rm30_plot = c1_vis_spy_rm30.rolling(window=30).mean().hvplot(
    title='First Dip - Vanguard Industrials Index Fund (VIS) & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VIS', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c1_vis_spy_rm30_plot


##########

# Plot a rolling 30-day mean of 3 ETFs and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c1_vaw_vcr_vis_spy_rm30 = pd.concat([c1_vaw_ss_csv, c1_vcr_ss_csv, c1_vis_ss_csv, c1_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c1_vaw_vcr_vis_spy_rm30.sort_index(inplace=True)

# Set column names
c1_vaw_vcr_vis_spy_rm30.columns = ['VAW', 'VCR', 'VIS', 'SPY']

# Display a few rows
c1_vaw_vcr_vis_spy_rm30.head()

c1_vaw_vcr_vis_spy_rm30_plot = c1_vaw_vcr_vis_spy_rm30.rolling(window=30).mean().hvplot(
    title='First Dip - Vanguard Materials (VAW), Discretionary (VCR), Industrials (VIS) Index Funds & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VAW', 'VCR', 'VIS', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c1_vaw_vcr_vis_spy_rm30_plot

# %%
c1_vaw_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
c1_vcr_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
c1_vis_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
c1_vaw_vcr_vis_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
# Plot a rolling 30-day mean of VAW & SP500 daily returns.

c1_vaw_vcr_vis_spy_rm30_returns = c1_vaw_vcr_vis_spy_rm30.pct_change().dropna()

c1_vaw_vcr_vis_spy_rm30_returns.head()

c1_vaw_vcr_vis_spy_rm30_returns_plot = c1_vaw_vcr_vis_spy_rm30_returns.rolling(window=30).mean().hvplot(
    title='First Dip - Vanguard Materials (VAW), Discretionary (VCR), Industrials (VIS) Index Funds & S&P500 (SPY) - 30-Day Rolling Mean of Daily Returns',
    x='Date', 
    y=['VAW', 'VCR', 'VIS', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

c1_vaw_vcr_vis_spy_rm30_returns_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
# Plot cumulative returns for second dip period. 

c1_vaw_vcr_vis_spy_cumulative_returns = (1 + c1_vaw_vcr_vis_spy_daily_returns).cumprod() - 1
c1_vaw_vcr_vis_spy_cumulative_returns

c1_vaw_vcr_vis_spy_cumulative_returns.tail()
# Out:
#                  SPY       VAW       VCR       VIS
# Date
# 2010-12-22 -0.007261  0.340324  0.152116  0.128303
# 2010-12-23 -0.008682  0.342946  0.148337  0.125174
# 2010-12-27 -0.008287  0.342127  0.145881  0.126912
# 2010-12-28 -0.006867  0.345076  0.141912  0.127955
# 2010-12-29 -0.006156  0.352941  0.145503  0.127260

# %%
c1_vaw_vcr_vis_spy_cumulative_returns_plot = c1_vaw_vcr_vis_spy_cumulative_returns[1244:].hvplot.bar(
    title='First Dip - Vanguard Materials (VAW), Discretionary (VCR), Industrials (VIS) Index Funds & S&P500 (SPY) - Cumulative Returns',
    xlabel='Market Secotrs',
    ylabel='Cumulative Return',
    height=400,
    width=1200
)
c1_vaw_vcr_vis_spy_cumulative_returns_plot
# Out:
# :Bars   [Date,Variable]   (value)

# %%
# Use the `std` function and multiply by the square root of the number of trading days in a year to get annualized volatility 
c1_vaw_vcr_vis_spy_volatility = c1_vaw_vcr_vis_spy_daily_returns.std() * np.sqrt(252)
c1_vaw_vcr_vis_spy_volatility.sort_values(inplace=True)
c1_vaw_vcr_vis_spy_volatility
# Out:
# SPY    0.249108
# VCR    0.273682
# VIS    0.274254
# VAW    0.324300
# dtype: float64

# %%
# Drop the five stocks with the highest volatility in daily returns - PERHAPS WE DO THIS ONCE ALL 11 SECTORS ARE COMBINED IN ONE DF? DROP THE WEAKEST 50%?
# daily_returns.drop(columns=['MU', 'WDC', 'JNJ', 'FANG', 'WRK'], inplace=True)
# daily_returns.head()

# Set weights for corresponding risk profile of stocks, use the `dot` function to multiply each weight by the corresponding stock daily return
# BK, LUV, NKE, SBUX, T
#weights = [0.15, 0.05, 0.10, 0.2, 0.50]
#portfolio_returns = daily_returns.dot(weights)
#portfolio_returns.head()

# Use the `cumprod` function to calculate cumulative returns
#cumulative_returns = (1 + portfolio_returns).cumprod()
#cumulative_returns.head()

# Plot the returns of the portfolio in terms of money
#initial_investment = 10000
#cumulative_profit = initial_investment * cumulative_returns
#cumulative_profit.plot()

# %% [markdown]
# ##### All of these ETFs were losers during the 2nd dip. S&P500 lost the least. It was also the least volatile.

# %% [markdown]
# ## Second Dip

# %%
# Second Dip DF
# Create a new pivot table where the columns are the closing prices for each ticker
c2_vaw_vcr_vis_spy_df = pd.concat([c2_spy_ss_csv, c2_vaw_ss_csv, c2_vcr_ss_csv, c2_vis_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c2_vaw_vcr_vis_spy_df.sort_index(inplace=True)

# Set column names
c2_vaw_vcr_vis_spy_df.columns = ['SPY', 'VAW', 'VCR', 'VIS']

# Display a few rows
c2_vaw_vcr_vis_spy_df.head()

# Use the `pct_change` function to calculate daily returns
c2_vaw_vcr_vis_spy_daily_returns = c2_vaw_vcr_vis_spy_df.pct_change().dropna()
c2_vaw_vcr_vis_spy_daily_returns.head()
# Out:
#                  SPY       VAW       VCR       VIS
# Date
# 2014-01-03 -0.000164 -0.001171 -0.001488  0.003645
# 2014-01-06 -0.002898 -0.006156 -0.006333 -0.006659
# 2014-01-07  0.006142 -0.000393  0.005811  0.005383
# 2014-01-08  0.000218  0.003934 -0.001118  0.000000
# 2014-01-09  0.000654 -0.002155 -0.002892  0.004243

# %%
c2_vaw_vcr_vis_spy_daily_returns.describe()
# Out:
#                SPY          VAW          VCR          VIS
# count  1005.000000  1005.000000  1005.000000  1005.000000
# mean      0.000409     0.000338     0.000412     0.000405
# std       0.007634     0.009897     0.008402     0.008708
# min      -0.040884    -0.045883    -0.040234    -0.042212
# 25%      -0.002783    -0.004925    -0.003833    -0.003984
# 50%       0.000492     0.000779     0.000889     0.000648
# 75%       0.004424     0.006040     0.005363     0.005362
# max       0.038394     0.037085     0.034792     0.030230

# %% [markdown]
# ##### Analysis of above chart goes here.

# %%
# Plot a rolling 30-day mean of VAW and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c2_vaw_spy_rm30 = pd.concat([c2_vaw_ss_csv, c2_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c2_vaw_spy_rm30.sort_index(inplace=True)

# Set column names
c2_vaw_spy_rm30.columns = ['VAW', 'SPY']

# Display a few rows
c2_vaw_spy_rm30.head()

c2_vaw_spy_rm30_plot = c2_vaw_spy_rm30.rolling(window=30).mean().hvplot(
    title='Second Dip - Vanguard Materials Index Fund (VAW) & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VAW', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c2_vaw_spy_rm30_plot

##########

# Plot a rolling 30-day mean of VCR and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c2_vcr_spy_rm30 = pd.concat([c2_vcr_ss_csv, c2_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c2_vcr_spy_rm30.sort_index(inplace=True)

# Set column names
c2_vcr_spy_rm30.columns = ['VCR', 'SPY']

# Display a few rows
c2_vcr_spy_rm30.head()

c2_vcr_spy_rm30_plot = c2_vcr_spy_rm30.rolling(window=30).mean().hvplot(
    title='Second Dip - Vanguard Consumer Discretionary Index Fund (VCR) & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VCR', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c2_vcr_spy_rm30_plot

##########

# Plot a rolling 30-day mean of VIS and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c2_vis_spy_rm30 = pd.concat([c2_vis_ss_csv, c2_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c2_vis_spy_rm30.sort_index(inplace=True)

# Set column names
c2_vis_spy_rm30.columns = ['VIS', 'SPY']

# Display a few rows
c2_vis_spy_rm30.head()

c2_vis_spy_rm30_plot = c2_vis_spy_rm30.rolling(window=30).mean().hvplot(
    title='Second Dip - Vanguard Industrials Index Fund (VIS) & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VIS', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c2_vis_spy_rm30_plot


##########

# Plot a rolling 30-day mean of 3 ETFs and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c2_vaw_vcr_vis_spy_rm30 = pd.concat([c2_vaw_ss_csv, c2_vcr_ss_csv, c2_vis_ss_csv, c2_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c2_vaw_vcr_vis_spy_rm30.sort_index(inplace=True)

# Set column names
c2_vaw_vcr_vis_spy_rm30.columns = ['VAW', 'VCR', 'VIS', 'SPY']

# Display a few rows
c2_vaw_vcr_vis_spy_rm30.head()

c2_vaw_vcr_vis_spy_rm30_plot = c2_vaw_vcr_vis_spy_rm30.rolling(window=30).mean().hvplot(
    title='Second Dip - Vanguard Materials (VAW), Discretionary (VCR), Industrials (VIS) Index Funds & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VAW', 'VCR', 'VIS', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c2_vaw_vcr_vis_spy_rm30_plot

# %%
c2_vaw_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
c2_vcr_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
c2_vis_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
c2_vaw_vcr_vis_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
# Plot a rolling 30-day mean of VAW & SP500 daily returns.

c2_vaw_vcr_vis_spy_rm30_returns = c2_vaw_vcr_vis_spy_rm30.pct_change().dropna()

c2_vaw_vcr_vis_spy_rm30_returns.head()

c2_vaw_vcr_vis_spy_rm30_returns_plot = c2_vaw_vcr_vis_spy_rm30_returns.rolling(window=30).mean().hvplot(
    title='Second Dip - Vanguard Materials (VAW), Discretionary (VCR), Industrials (VIS) Index Funds & S&P500 (SPY) - 30-Day Rolling Mean of Daily Returns',
    x='Date', 
    y=['VAW', 'VCR', 'VIS', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

c2_vaw_vcr_vis_spy_rm30_returns_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
# Plot cumulative returns for second dip period. 

c2_vaw_vcr_vis_spy_cumulative_returns = (1 + c2_vaw_vcr_vis_spy_daily_returns).cumprod() - 1
c2_vaw_vcr_vis_spy_cumulative_returns

c2_vaw_vcr_vis_spy_cumulative_returns.tail()
# Out:
#                  SPY       VAW       VCR       VIS
# Date
# 2017-12-21  0.462825  0.324614  0.460108  0.437930
# 2017-12-22  0.462443  0.329104  0.456760  0.437323
# 2017-12-26  0.460693  0.329690  0.458527  0.439449
# 2017-12-27  0.461404  0.330666  0.455551  0.442993
# 2017-12-28  0.464411  0.337205  0.459922  0.446031

# %%
c2_vaw_vcr_vis_spy_cumulative_returns_plot = c2_vaw_vcr_vis_spy_cumulative_returns[1004:].hvplot.bar(
    title='Second Dip - Vanguard Materials (VAW), Discretionary (VCR), Industrials (VIS) Index Funds & S&P500 (SPY) - Cumulative Returns',
    xlabel='Market Secotrs',
    ylabel='Cumulative Return',
    height=400,
    width=1200
)
c2_vaw_vcr_vis_spy_cumulative_returns_plot
# Out:
# :Bars   [Date,Variable]   (value)

# %% [markdown]
# ## Third Dip

# %%
# Third Dip DF
# Create a new pivot table where the columns are the closing prices for each ticker
c3_vaw_vcr_vis_spy_df = pd.concat([c3_spy_ss_csv, c3_vaw_ss_csv, c3_vcr_ss_csv, c3_vis_ss_csv], axis="columns", join="inner")


# Sort datetime index in ascending order (past to present)
c3_vaw_vcr_vis_spy_df.sort_index(inplace=True)

# Set column names
c3_vaw_vcr_vis_spy_df.columns = ['SPY', 'VAW', 'VCR', 'VIS']

# Display a few rows
c3_vaw_vcr_vis_spy_df.head()


# Use the `pct_change` function to calculate daily returns
c3_vaw_vcr_vis_spy_daily_returns = c3_vaw_vcr_vis_spy_df.pct_change().dropna()
c3_vaw_vcr_vis_spy_daily_returns.head(-1)
# Out:
#                  SPY       VAW       VCR       VIS
# Date
# 2017-01-04  0.005949  0.017027  0.014545  0.006831
# 2017-01-05 -0.000794 -0.003643 -0.000839 -0.005295
# 2017-01-06  0.003578 -0.002264  0.001984  0.003078
# 2017-01-09 -0.003301 -0.002531 -0.000838 -0.007132
# 2017-01-10  0.000000  0.005074  0.005032  0.004928
# ...              ...       ...       ...       ...
# 2019-12-19  0.004099  0.003026  0.003846  0.002093
# 2019-12-20 -0.000530  0.002187  0.000904  0.005612
# 2019-12-23  0.001528  0.005870 -0.000372  0.005516
# 2019-12-24  0.000031  0.000973  0.002340 -0.003356
# 2019-12-26  0.005323  0.003139  0.011088  0.002784
#
# [750 rows x 4 columns]

# %%
c3_vaw_vcr_vis_spy_daily_returns.describe()
# Out:
#               SPY         VAW         VCR         VIS
# count  751.000000  751.000000  751.000000  751.000000
# mean     0.000512    0.000267    0.000561    0.000382
# std      0.008104    0.009796    0.009303    0.009537
# min     -0.041822   -0.036083   -0.039313   -0.045657
# 25%     -0.002325   -0.005091   -0.003842   -0.003855
# 50%      0.000549    0.000610    0.001204    0.000960
# 75%      0.004513    0.005983    0.005468    0.005741
# max      0.050525    0.044210    0.061251    0.047134

# %%
# Plot a rolling 30-day mean of VAW and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c3_vaw_spy_rm30 = pd.concat([c3_vaw_ss_csv, c3_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c3_vaw_spy_rm30.sort_index(inplace=True)

# Set column names
c3_vaw_spy_rm30.columns = ['VAW', 'SPY']

# Display a few rows
c3_vaw_spy_rm30.head()

c3_vaw_spy_rm30_plot = c3_vaw_spy_rm30.rolling(window=30).mean().hvplot(
    title='Third Dip - Vanguard Materials Index Fund (VAW) & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VAW', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c3_vaw_spy_rm30_plot

##########

# Plot a rolling 30-day mean of VCR and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c3_vcr_spy_rm30 = pd.concat([c3_vcr_ss_csv, c3_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c3_vcr_spy_rm30.sort_index(inplace=True)

# Set column names
c3_vcr_spy_rm30.columns = ['VCR', 'SPY']

# Display a few rows
c3_vcr_spy_rm30.head()

c3_vcr_spy_rm30_plot = c3_vcr_spy_rm30.rolling(window=30).mean().hvplot(
    title='Third Dip - Vanguard Consumer Discretionary Index Fund (VCR) & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VCR', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c3_vcr_spy_rm30_plot

##########

# Plot a rolling 30-day mean of VIS and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c3_vis_spy_rm30 = pd.concat([c3_vis_ss_csv, c3_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c3_vis_spy_rm30.sort_index(inplace=True)

# Set column names
c3_vis_spy_rm30.columns = ['VIS', 'SPY']

# Display a few rows
c3_vis_spy_rm30.head()

c3_vis_spy_rm30_plot = c3_vis_spy_rm30.rolling(window=30).mean().hvplot(
    title='Third Dip - Vanguard Industrials Index Fund (VIS) & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VIS', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c3_vis_spy_rm30_plot


##########

# Plot a rolling 30-day mean of 3 ETFs and SP500 closing prices

# Create a new pivot table where the columns are the closing prices for each ticker
c3_vaw_vcr_vis_spy_rm30 = pd.concat([c3_vaw_ss_csv, c3_vcr_ss_csv, c3_vis_ss_csv, c3_spy_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
c3_vaw_vcr_vis_spy_rm30.sort_index(inplace=True)

# Set column names
c3_vaw_vcr_vis_spy_rm30.columns = ['VAW', 'VCR', 'VIS', 'SPY']

# Display a few rows
c3_vaw_vcr_vis_spy_rm30.head()

c3_vaw_vcr_vis_spy_rm30_plot = c3_vaw_vcr_vis_spy_rm30.rolling(window=30).mean().hvplot(
    title='Third Dip - Vanguard Materials (VAW), Discretionary (VCR), Industrials (VIS) Index Funds & S&P500 (SPY) - 30-Day Rolling Mean of Closing Prices',
    x='Date', 
    y=['VAW', 'VCR', 'VIS', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

# To render use: c3_vaw_vcr_vis_spy_rm30_plot

# %%
c3_vaw_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
c3_vcr_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
c3_vis_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
c3_vaw_vcr_vis_spy_rm30_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
# Plot a rolling 30-day mean of VAW & SP500 daily returns.

c3_vaw_vcr_vis_spy_rm30_returns = c3_vaw_vcr_vis_spy_rm30.pct_change().dropna()

c3_vaw_vcr_vis_spy_rm30_returns.head()

c3_vaw_vcr_vis_spy_rm30_returns_plot = c3_vaw_vcr_vis_spy_rm30_returns.rolling(window=30).mean().hvplot(
    title='Third Dip - Vanguard Materials (VAW), Discretionary (VCR), Industrials (VIS) Index Funds & S&P500 (SPY) - 30-Day Rolling Mean of Daily Returns',
    x='Date', 
    y=['VAW', 'VCR', 'VIS', 'SPY'], 
    value_label='Closing Price',
    height=400,
    width=1200)

c3_vaw_vcr_vis_spy_rm30_returns_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (Closing Price)

# %%
# Plot cumulative returns for third dip period. 

c3_vaw_vcr_vis_spy_cumulative_returns = (1 + c3_vaw_vcr_vis_spy_daily_returns).cumprod() - 1
c3_vaw_vcr_vis_spy_cumulative_returns

c3_vaw_vcr_vis_spy_cumulative_returns.tail()
# Out:
#                  SPY       VAW       VCR       VIS
# Date
# 2019-12-20  0.423948  0.172210  0.455474  0.283739
# 2019-12-23  0.426123  0.179091  0.454932  0.290820
# 2019-12-24  0.426168  0.180238  0.458337  0.286488
# 2019-12-26  0.433760  0.183944  0.474507  0.290070
# 2019-12-27  0.433404  0.178562  0.474662  0.287821

# %%
c3_vaw_vcr_vis_spy_cumulative_returns_plot = c3_vaw_vcr_vis_spy_cumulative_returns[750:].hvplot.bar(
    title='Third Dip - Vanguard Materials (VAW), Discretionary (VCR), Industrials (VIS) Index Funds & S&P500 (SPY) - Cumulative Returns',
    xlabel='Market Sectors',
    ylabel='Cumulative Return',
    height=400,
    width=1200
)
c3_vaw_vcr_vis_spy_cumulative_returns_plot
# Out:
# :Bars   [Date,Variable]   (value)

# %%
c1_cumulative_returns = c1_vaw_vcr_vis_spy_cumulative_returns[1244:]
c1_cumulative_returns
list_of_crashes_1 = ['Crash 1']
c1_cumulative_returns.loc[:,'Market_Crash']=list_of_crashes_1

c2_cumulative_returns = c2_vaw_vcr_vis_spy_cumulative_returns[1004:]
c2_cumulative_returns
list_of_crashes_2 = ['Crash 2']
c2_cumulative_returns.loc[:,'Market_Crash']=list_of_crashes_2

c3_cumulative_returns = c3_vaw_vcr_vis_spy_cumulative_returns[750:]
c3_cumulative_returns
list_of_crashes_3 = ['Crash 3']
c3_cumulative_returns.loc[:,'Market_Crash']=list_of_crashes_3

c123_cumulative_returns = pd.concat([c1_cumulative_returns,c2_cumulative_returns,c3_cumulative_returns],
    axis="rows",
    join="inner"
)


c123_cumulative_returns.set_index(c123_cumulative_returns['Market_Crash'], inplace=True)

c123_cumulative_returns.set_index('Market_Crash').hvplot(
    title="Across Three Crashes - Vanguard Materials (VAW), Discretionary (VCR), Industrials (VIS) Index Funds & S&P500 (SPY) - Cumulative Returns",
    kind='bar',
    xlabel='Three Market Crash Periods',
    ylabel='Cumulative Daily Returns',
    stacked=False,
    height=400,
    width=1200,
    hover_color='red'
)
# Out:
# C:\Users\Steve Stark REALTOR\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Steve Stark REALTOR\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# :Bars   [Market_Crash,Variable]   (value)

# %% [markdown]
# # All 11 Sectors Together

# %%
# First Dip DF
# Create a new pivot table where the columns are the closing prices for each ticker
c1_all_sectors_df = pd.concat([c1_spy_ss_csv, c1_vaw_ss_csv, c1_vcr_ss_csv, c1_vis_ss_csv,
                                c1_iyr_jp,c1_vnq_jp,c1_vdc_js_csv,c1_xlp_js_csv,
                                c1_xlf_af,c1_vht_af,c1_vgt_ks_csv,c1_vde_ks_csv], 
                                axis="columns", 
                                join="inner"
)

# Sort datetime index in ascending order (past to present)
c1_all_sectors_df.sort_index(inplace=True)

# Set column names
c1_all_sectors_df.columns = ['SPY', 'VAW', 'VCR', 'VIS', 'IYR', 'VNQ', 'VDC', 'XLP', 'XLF', 'VHT', 'VGT', 'VDE']

# Display a few rows
c1_all_sectors_df.head()

# Use the `pct_change` function to calculate daily returns
c1_all_sectors_daily_returns = c1_all_sectors_df.pct_change().dropna()
c1_all_sectors_daily_returns.head()


# Second Dip DF
# Create a new pivot table where the columns are the closing prices for each ticker
c2_all_sectors_df = pd.concat([c2_spy_ss_csv, c2_vaw_ss_csv, c2_vcr_ss_csv, c2_vis_ss_csv,
                                c2_iyr_jp,c2_vnq_jp,c2_vdc_js_csv,c2_xlp_js_csv,
                                c2_xlf_af,c2_vht_af,c2_vgt_ks_csv,c2_vde_ks_csv], 
                                axis="columns", 
                                join="inner"
)

# Sort datetime index in ascending order (past to present)
c2_all_sectors_df.sort_index(inplace=True)

# Set column names
c2_all_sectors_df.columns = ['SPY', 'VAW', 'VCR', 'VIS', 'IYR', 'VNQ', 'VDC', 'XLP', 'XLF', 'VHT', 'VGT', 'VDE']

# Display a few rows
c2_all_sectors_df.head()

# Use the `pct_change` function to calculate daily returns
c2_all_sectors_daily_returns = c2_all_sectors_df.pct_change().dropna()
c2_all_sectors_daily_returns.head()


# Third Dip DF
# Create a new pivot table where the columns are the closing prices for each ticker
c3_all_sectors_df = pd.concat([c3_spy_ss_csv, c3_vaw_ss_csv, c3_vcr_ss_csv, c3_vis_ss_csv,
                                c3_iyr_jp,c3_vnq_jp,c3_vdc_js_csv,c3_xlp_js_csv,
                                c3_xlf_af,c3_vht_af,c3_vgt_ks_csv,c3_vde_ks_csv], 
                                axis="columns", 
                                join="inner"
)

# Sort datetime index in ascending order (past to present)
c3_all_sectors_df.sort_index(inplace=True)

# Set column names
c3_all_sectors_df.columns = ['SPY', 'VAW', 'VCR', 'VIS', 'IYR', 'VNQ', 'VDC', 'XLP', 'XLF', 'VHT', 'VGT', 'VDE']

# Display a few rows
c3_all_sectors_df.head()

# Use the `pct_change` function to calculate daily returns
c3_all_sectors_daily_returns = c3_all_sectors_df.pct_change().dropna()
c3_all_sectors_daily_returns.head()
# Out:
#                  SPY       VAW       VCR       VIS       IYR       VNQ  \
# Date
# 2017-01-04  0.005949  0.017027  0.014545  0.006831  0.008256  0.006865
# 2017-01-05 -0.000794 -0.003643 -0.000839 -0.005295  0.012032 -0.007299
# 2017-01-06  0.003578 -0.002264  0.001984  0.003078 -0.008091 -0.013834
# 2017-01-09 -0.003301 -0.002531 -0.000838 -0.007132 -0.006992 -0.009712
# 2017-01-10  0.000000  0.005074  0.005032  0.004928  0.001174  0.005944
#
#                  VDC       XLP       XLF       VHT       VGT       VDE
# Date
# 2017-01-04  0.001562  0.000000  0.008082  0.009740  0.009740 -0.000283
# 2017-01-05  0.001783  0.003276 -0.010127  0.004321  0.004321 -0.002739
# 2017-01-06 -0.000371  0.000960  0.003410  0.003073  0.003073 -0.000284
# 2017-01-09 -0.006675 -0.008058 -0.006797  0.007583  0.007583 -0.015820
# 2017-01-10 -0.005451 -0.005029  0.002139  0.003573  0.003573 -0.009048

# %%
c1_all_sectors_described = c1_all_sectors_daily_returns.describe()
c1_all_sectors_described

c2_all_sectors_described = c2_all_sectors_daily_returns.describe()
c2_all_sectors_described

c3_all_sectors_described = c3_all_sectors_daily_returns.describe()
c3_all_sectors_described
# Out:
#               SPY         VAW         VCR         VIS         IYR         VNQ  \
# count  751.000000  751.000000  751.000000  751.000000  751.000000  751.000000
# mean     0.000512    0.000267    0.000561    0.000382    0.000092   -0.000067
# std      0.008104    0.009796    0.009303    0.009537    0.008259    0.010090
# min     -0.041822   -0.036083   -0.039313   -0.045657   -0.040850   -0.049802
# 25%     -0.002325   -0.005091   -0.003842   -0.003855   -0.004239   -0.005412
# 50%      0.000549    0.000610    0.001204    0.000960    0.000339    0.000505
# 75%      0.004513    0.005983    0.005468    0.005741    0.004549    0.005821
# max      0.050525    0.044210    0.061251    0.047134    0.038054    0.054198
#
#               VDC         XLP         XLF         VHT         VGT         VDE
# count  751.000000  751.000000  751.000000  751.000000  751.000000  751.000000
# mean     0.000272    0.000289    0.000412    0.000580    0.000580   -0.000276
# ...

# %%
c1_all_sectors_described
# Out:
#               SPY         VAW         VCR         VIS         IYR         VNQ  \
# count  875.000000  875.000000  875.000000  875.000000  875.000000  875.000000
# mean    -0.000042    0.000275    0.000151    0.000084   -0.000970    0.000204
# std      0.018195    0.023328    0.019962    0.019907    0.026715    0.035070
# min     -0.098448   -0.123041   -0.093891   -0.093129   -0.161030   -0.207002
# 25%     -0.008080   -0.010386   -0.009952   -0.008765   -0.011374   -0.016144
# 50%      0.000527    0.001409    0.000822    0.000743   -0.000205   -0.000448
# 75%      0.007714    0.013282    0.009920    0.009299    0.009701    0.014898
# max      0.145198    0.108867    0.110615    0.093930    0.139988    0.170065
#
#               VDC         XLP         XLF         VHT         VGT         VDE
# count  875.000000  875.000000  875.000000  875.000000  875.000000  875.000000
# mean     0.000170    0.000150   -0.000396   -0.000002    0.000267    0.000388
# ...

# %%
# STD and Mean for Grouing During First Dip
c1_spy_std = c1_all_sectors_described.loc['std','SPY']
c1_vaw_std = c1_all_sectors_described.loc['std','VAW']
c1_vcr_std = c1_all_sectors_described.loc['std','VCR']
c1_vis_std = c1_all_sectors_described.loc['std','VIS']
c1_iyr_std = c1_all_sectors_described.loc['std','IYR']
c1_vnq_std = c1_all_sectors_described.loc['std','VNQ']
c1_vdc_std = c1_all_sectors_described.loc['std','VDC']
c1_xlp_std = c1_all_sectors_described.loc['std','XLP']
c1_xlf_std = c1_all_sectors_described.loc['std','XLF']
c1_vht_std = c1_all_sectors_described.loc['std','VHT']
c1_vgt_std = c1_all_sectors_described.loc['std','VGT']
c1_vde_std = c1_all_sectors_described.loc['std','VDE']
c1_spy_mean = c1_all_sectors_described.loc['mean','SPY']
c1_vaw_mean = c1_all_sectors_described.loc['mean','VAW']
c1_vcr_mean = c1_all_sectors_described.loc['mean','VCR']
c1_vis_mean = c1_all_sectors_described.loc['mean','VIS']
c1_iyr_mean = c1_all_sectors_described.loc['mean','IYR']
c1_vnq_mean = c1_all_sectors_described.loc['mean','VNQ']
c1_vdc_mean = c1_all_sectors_described.loc['mean','VDC']
c1_xlp_mean = c1_all_sectors_described.loc['mean','XLP']
c1_xlf_mean = c1_all_sectors_described.loc['mean','XLF']
c1_vht_mean = c1_all_sectors_described.loc['mean','VHT']
c1_vgt_mean = c1_all_sectors_described.loc['mean','VGT']
c1_vde_mean = c1_all_sectors_described.loc['mean','VDE']

# STD and Mean for Grouing During Second Dip
c2_spy_std = c2_all_sectors_described.loc['std','SPY']
c2_vaw_std = c2_all_sectors_described.loc['std','VAW']
c2_vcr_std = c2_all_sectors_described.loc['std','VCR']
c2_vis_std = c2_all_sectors_described.loc['std','VIS']
c2_iyr_std = c2_all_sectors_described.loc['std','IYR']
c2_vnq_std = c2_all_sectors_described.loc['std','VNQ']
c2_vdc_std = c2_all_sectors_described.loc['std','VDC']
c2_xlp_std = c2_all_sectors_described.loc['std','XLP']
c2_xlf_std = c2_all_sectors_described.loc['std','XLF']
c2_vht_std = c2_all_sectors_described.loc['std','VHT']
c2_vgt_std = c2_all_sectors_described.loc['std','VGT']
c2_vde_std = c2_all_sectors_described.loc['std','VDE']
c2_spy_mean = c2_all_sectors_described.loc['mean','SPY']
c2_vaw_mean = c2_all_sectors_described.loc['mean','VAW']
c2_vcr_mean = c2_all_sectors_described.loc['mean','VCR']
c2_vis_mean = c2_all_sectors_described.loc['mean','VIS']
c2_iyr_mean = c2_all_sectors_described.loc['mean','IYR']
c2_vnq_mean = c2_all_sectors_described.loc['mean','VNQ']
c2_vdc_mean = c2_all_sectors_described.loc['mean','VDC']
c2_xlp_mean = c2_all_sectors_described.loc['mean','XLP']
c2_xlf_mean = c2_all_sectors_described.loc['mean','XLF']
c2_vht_mean = c2_all_sectors_described.loc['mean','VHT']
c2_vgt_mean = c2_all_sectors_described.loc['mean','VGT']
c2_vde_mean = c2_all_sectors_described.loc['mean','VDE']

# STD and Mean for Grouing During Second Dip

c3_spy_std = c3_all_sectors_described.loc['std','SPY']
c3_vaw_std = c3_all_sectors_described.loc['std','VAW']
c3_vcr_std = c3_all_sectors_described.loc['std','VCR']
c3_vis_std = c3_all_sectors_described.loc['std','VIS']
c3_iyr_std = c3_all_sectors_described.loc['std','IYR']
c3_vnq_std = c3_all_sectors_described.loc['std','VNQ']
c3_vdc_std = c3_all_sectors_described.loc['std','VDC']
c3_xlp_std = c3_all_sectors_described.loc['std','XLP']
c3_xlf_std = c3_all_sectors_described.loc['std','XLF']
c3_vht_std = c3_all_sectors_described.loc['std','VHT']
c3_vgt_std = c3_all_sectors_described.loc['std','VGT']
c3_vde_std = c3_all_sectors_described.loc['std','VDE']
c3_spy_mean = c3_all_sectors_described.loc['mean','SPY']
c3_vaw_mean = c3_all_sectors_described.loc['mean','VAW']
c3_vcr_mean = c3_all_sectors_described.loc['mean','VCR']
c3_vis_mean = c3_all_sectors_described.loc['mean','VIS']
c3_iyr_mean = c3_all_sectors_described.loc['mean','IYR']
c3_vnq_mean = c3_all_sectors_described.loc['mean','VNQ']
c3_vdc_mean = c3_all_sectors_described.loc['mean','VDC']
c3_xlp_mean = c3_all_sectors_described.loc['mean','XLP']
c3_xlf_mean = c3_all_sectors_described.loc['mean','XLF']
c3_vht_mean = c3_all_sectors_described.loc['mean','VHT']
c3_vgt_mean = c3_all_sectors_described.loc['mean','VGT']
c3_vde_mean = c3_all_sectors_described.loc['mean','VDE']

# %%
# Calculate mean daily returns for all sectors. 
c1_all_sectors_mean = pd.DataFrame(columns=['SPY', 'VAW', 'VCR', 'VIS', 'IYR', 'VNQ', 'VDC', 'XLP', 'XLF', 'VHT', 'VGT', 'VDE'])
c1_all_sectors_mean['SPY']=[c1_spy_mean]
c1_all_sectors_mean['VAW']=[c1_vaw_mean]
c1_all_sectors_mean['VCR']=[c1_vcr_mean]
c1_all_sectors_mean['VIS']=[c1_vis_mean]
c1_all_sectors_mean['IYR']=[c1_iyr_mean]
c1_all_sectors_mean['VNQ']=[c1_vnq_mean]
c1_all_sectors_mean['VDC']=[c1_vdc_mean]
c1_all_sectors_mean['XLP']=[c1_xlp_mean]
c1_all_sectors_mean['XLF']=[c1_xlf_mean]
c1_all_sectors_mean['VHT']=[c1_vht_mean]
c1_all_sectors_mean['VGT']=[c1_vgt_mean]
c1_all_sectors_mean['VDE']=[c1_vde_mean]

# c1_all_sectors_mean.head()

c2_all_sectors_mean = pd.DataFrame(columns=['SPY', 'VAW', 'VCR', 'VIS', 'IYR', 'VNQ', 'VDC', 'XLP', 'XLF', 'VHT', 'VGT', 'VDE'])
c2_all_sectors_mean['SPY']=[c2_spy_mean]
c2_all_sectors_mean['VAW']=[c2_vaw_mean]
c2_all_sectors_mean['VCR']=[c2_vcr_mean]
c2_all_sectors_mean['VIS']=[c2_vis_mean]
c2_all_sectors_mean['IYR']=[c2_iyr_mean]
c2_all_sectors_mean['VNQ']=[c2_vnq_mean]
c2_all_sectors_mean['VDC']=[c2_vdc_mean]
c2_all_sectors_mean['XLP']=[c2_xlp_mean]
c2_all_sectors_mean['XLF']=[c2_xlf_mean]
c2_all_sectors_mean['VHT']=[c2_vht_mean]
c2_all_sectors_mean['VGT']=[c2_vgt_mean]
c2_all_sectors_mean['VDE']=[c2_vde_mean]

# c2_all_sectors_mean.head()

c3_all_sectors_mean = pd.DataFrame(columns=['SPY', 'VAW', 'VCR', 'VIS', 'IYR', 'VNQ', 'VDC', 'XLP', 'XLF', 'VHT', 'VGT', 'VDE'])
c3_all_sectors_mean['SPY']=[c3_spy_mean]
c3_all_sectors_mean['VAW']=[c3_vaw_mean]
c3_all_sectors_mean['VCR']=[c3_vcr_mean]
c3_all_sectors_mean['VIS']=[c3_vis_mean]
c3_all_sectors_mean['IYR']=[c3_iyr_mean]
c3_all_sectors_mean['VNQ']=[c3_vnq_mean]
c3_all_sectors_mean['VDC']=[c3_vdc_mean]
c3_all_sectors_mean['XLP']=[c3_xlp_mean]
c3_all_sectors_mean['XLF']=[c3_xlf_mean]
c3_all_sectors_mean['VHT']=[c3_vht_mean]
c3_all_sectors_mean['VGT']=[c3_vgt_mean]
c3_all_sectors_mean['VDE']=[c3_vde_mean]

c3_all_sectors_mean.head()
# Out:
#         SPY       VAW       VCR       VIS       IYR       VNQ       VDC  \
# 0  0.000512  0.000267  0.000561  0.000382  0.000092 -0.000067  0.000272
#
#         XLP       XLF      VHT      VGT       VDE
# 0  0.000289  0.000412  0.00058  0.00058 -0.000276

# %%
# Plotting combined bar charts for avg daily returns of all sectors across three market crashes

c1_all_sectors_barchart = c1_all_sectors_mean.hvplot.bar(
    title="First Dip - Mean Daily Returns of All Sectors - 01/03/2006 to 12/30/2010",
    xlabel="Market Sectors",
    ylabel="Mean Daily Returns - First Dip",
    yformatter='%.8f',
    height=400,
    width=1200
)

# To render: c1_all_sectors_barchart


c2_all_sectors_barchart = c2_all_sectors_mean.hvplot.bar(
    title="Second Dip - Mean Daily Returns of All Sectors - 01/02/2014 to 12/29/2017",
    xlabel="Market Sectors",
    ylabel="Mean Daily Returns - Second Dip",
    yformatter='%.8f',
    height=400,
    width=1200
)

# To render: c2_all_sectors_barchart


c3_all_sectors_barchart = c3_all_sectors_mean.hvplot.bar(
    title="Third Dip - Mean Daily Returns of All Sectors - 01/03/2017 to 12/30/2019",
    xlabel="Market Sectors",
    ylabel="Mean Daily Returns - Third Dip",
    yformatter='%.8f',
    height=400,
    width=1200
)

# To render: c3_all_sectors_barchart

# %%
c1_all_sectors_barchart
# Out:
# :Bars   [index,Variable]   (value)

# %%
c1_all_sectors_mean
# Out:
#         SPY       VAW       VCR       VIS      IYR       VNQ      VDC  \
# 0 -0.000042  0.000275  0.000151  0.000084 -0.00097  0.000204  0.00017
#
#        XLP       XLF       VHT       VGT       VDE
# 0  0.00015 -0.000396 -0.000002  0.000267  0.000388

# %%
c2_all_sectors_barchart
# Out:
# :Bars   [index,Variable]   (value)

# %%
c2_all_sectors_mean
# Out:
#         SPY       VAW       VCR       VIS       IYR       VNQ       VDC  \
# 0  0.000409  0.000338  0.000412  0.000405 -0.000069  0.000143  0.000316
#
#         XLP       XLF       VHT       VGT       VDE
# 0  0.000316  0.000844  0.000476  0.000667 -0.000132

# %%
c3_all_sectors_barchart
# Out:
# :Bars   [index,Variable]   (value)

# %%
c3_all_sectors_mean
# Out:
#         SPY       VAW       VCR       VIS       IYR       VNQ       VDC  \
# 0  0.000512  0.000267  0.000561  0.000382  0.000092 -0.000067  0.000272
#
#         XLP       XLF      VHT      VGT       VDE
# 0  0.000289  0.000412  0.00058  0.00058 -0.000276

# %%
all_crashes_all_sectors_mean = pd.concat([c1_all_sectors_mean,c2_all_sectors_mean,c3_all_sectors_mean], axis="rows", join="inner").reset_index()
all_crashes_all_sectors_mean
# Out:
#    index       SPY       VAW       VCR       VIS       IYR       VNQ  \
# 0      0 -0.000042  0.000275  0.000151  0.000084 -0.000970  0.000204
# 1      0  0.000409  0.000338  0.000412  0.000405 -0.000069  0.000143
# 2      0  0.000512  0.000267  0.000561  0.000382  0.000092 -0.000067
#
#         VDC       XLP       XLF       VHT       VGT       VDE
# 0  0.000170  0.000150 -0.000396 -0.000002  0.000267  0.000388
# 1  0.000316  0.000316  0.000844  0.000476  0.000667 -0.000132
# 2  0.000272  0.000289  0.000412  0.000580  0.000580 -0.000276

# %%
all_crashes_all_sectors_mean = all_crashes_all_sectors_mean.rename(columns={'index': 'Crash'})
all_crashes_all_sectors_mean['Crash'].iloc[0]=('Crash 1')
all_crashes_all_sectors_mean['Crash'].iloc[1]=('Crash 2')
all_crashes_all_sectors_mean['Crash'].iloc[2]=('Crash 3')
all_crashes_all_sectors_mean
# Out:
# C:\Users\Steve Stark REALTOR\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#      Crash       SPY       VAW       VCR       VIS       IYR       VNQ  \
# 0  Crash 1 -0.000042  0.000275  0.000151  0.000084 -0.000970  0.000204
# 1  Crash 2  0.000409  0.000338  0.000412  0.000405 -0.000069  0.000143
# 2  Crash 3  0.000512  0.000267  0.000561  0.000382  0.000092 -0.000067
#
#         VDC       XLP       XLF       VHT       VGT       VDE
# 0  0.000170  0.000150 -0.000396 -0.000002  0.000267  0.000388
# 1  0.000316  0.000316  0.000844  0.000476  0.000667 -0.000132
# 2  0.000272  0.000289  0.000412  0.000580  0.000580 -0.000276

# %%
import plotly.express as px
all_crashes_all_sectors_mean_sunburst_df = px.all_crashes_all_sectors_mean.tips()
all_crashes_all_sectors_mean_fig = px.sunburst(all_crashes_all_sectors_mean_sunburst_df, path=['Crash', 'time', 'sex'], values='total_bill')
all_crashes_all_sectors_mean_fig.show()

# %%
crash_list = ['Crash 1', 'Crash 2', 'Crash 3']


#column_values = pd.Series(mylist)
#df.insert(loc=0, column='new_column', value=column_values)

# %%
# Drop unnecessary columns
amd_csv.drop(columns=['volume', 'open', 'high', 'low'], inplace=True)
amd_csv.head()

# %%
# All Crashes - Top Performers based on avg daily return
c123_avg_return_sunburst_csv = pd.read_csv(
    Path("c123_avg_return_sunburst_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True
).drop(columns=['Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12'])
c123_avg_return_sunburst_csv
# Out:
#      Crash Ticker  Avg. Daily Return
# 0  Crash 1    VDE           0.000388
# 1  Crash 1    VGT           0.000267
# 2  Crash 1    VAW           0.000275
# 3  Crash 2    XLF           0.000844
# 4  Crash 2    VGT           0.000667
# 5  Crash 2    VHT           0.000476
# 6  Crash 3    VHT           0.000580
# 7  Crash 3    VGT           0.000580
# 8  Crash 3    VCR           0.000561

# %%
import plotly.express as px

# %%
c123_avg_return_sunburst_csv_fig = px.sunburst(
    c123_avg_return_sunburst_csv, 
    path=['Crash', 'Ticker'], 
    values='Avg. Daily Return',
    title='Sectors Which Outperformed S&P500 in Avg Daily Returns Across Three Market Crashes',
    height=800,
    width=1000
)

c123_avg_return_sunburst_csv_fig.show()

# %%
#help(px)

# %%
c3_all_sectors_cumulative_returns[750:]
# Out:
#                  SPY       VAW       VCR       VIS       IYR       VNQ  \
# Date
# 2019-12-27  0.433404  0.178562  0.474662  0.287821  0.044313 -0.084413
#
#                  VDC      XLP       XLF       VHT       VGT       VDE
# Date
# 2019-12-27  0.204493  0.21869  0.308805  0.500701  0.500701 -0.233217

# %%
c3_all_sectors_cumulative_returns.tail()
# Out:
#                  SPY       VAW       VCR       VIS       IYR       VNQ  \
# Date
# 2019-12-20  0.423948  0.172210  0.455474  0.283739  0.040101 -0.087120
# 2019-12-23  0.426123  0.179091  0.454932  0.290820  0.039090 -0.088861
# 2019-12-24  0.426168  0.180238  0.458337  0.286488  0.037405 -0.089731
# 2019-12-26  0.433760  0.183944  0.474507  0.290070  0.042628 -0.082673
# 2019-12-27  0.433404  0.178562  0.474662  0.287821  0.044313 -0.084413
#
#                  VDC       XLP       XLF       VHT       VGT       VDE
# Date
# 2019-12-20  0.200922  0.215800  0.304977  0.495870  0.495870 -0.237749
# 2019-12-23  0.196608  0.210597  0.301999  0.503195  0.503195 -0.228307
# 2019-12-24  0.197947  0.212139  0.304977  0.504363  0.504363 -0.228307
# 2019-12-26  0.199509  0.213295  0.312208  0.500623  0.500623 -0.228874
# 2019-12-27  0.204493  0.218690  0.308805  0.500701  0.500701 -0.233217

# %%
# Plotting combined bar charts for cumulative returns of all sectors across three market crashes

c1_all_sectors_cumulative_returns_barchart = c1_all_sectors_cumulative_returns[874:].hvplot.bar(
    title="First Dip - Cumulative Returns of All Sectors - 01/03/2006 to 12/30/2010",
    xlabel="Market Sectors",
    ylabel="Cumulative Returns - First Dip",
    yformatter='%.8f',
    height=400,
    width=1200,
    cmap='Set3'
)

# To render: c1_all_sectors_barchart


c2_all_sectors_cumulative_returns_barchart = c2_all_sectors_cumulative_returns[1004:].hvplot.bar(
    title="Second Dip - Cumulative Returns of All Sectors - 01/02/2014 to 12/29/2017",
    xlabel="Market Sectors",
    ylabel="Cumulative Returns - Second Dip",
    yformatter='%.8f',
    height=400,
    width=1200,
    cmap='Set3'
)

# To render: c2_all_sectors_barchart


c3_all_sectors_cumulative_returns_barchart = c3_all_sectors_cumulative_returns[750:].hvplot.bar(
    title="Third Dip - Cumulative Returns of All Sectors - 01/03/2017 to 12/30/2019",
    xlabel="Market Sectors",
    ylabel="Cumulative Returns - Third Dip",
    yformatter='%.8f',
    height=400,
    width=1200,
    cmap='Set3'
)

# %%
(cmap='Summer', colorbar=True, toolbar='above')

# %%
c1_all_sectors_cumulative_returns_barchart
# Out:
# :Bars   [Date,Variable]   (value)

# %%
c1_all_sectors_cumulative_returns[874:]
# Out:
#                  SPY       VAW       VCR       VIS     IYR      VNQ       VDC  \
# Date
# 2010-12-29 -0.165319  0.001091 -0.041126 -0.095424 -0.6877 -0.30183  0.091747
#
#                  XLP       XLF       VHT       VGT      VDE
# Date
# 2010-12-29  0.079044 -0.576537 -0.081914  0.093628  0.04534

# %%
c2_all_sectors_cumulative_returns_barchart
# Out:
# :Bars   [Date,Variable]   (value)

# %%
c2_all_sectors_cumulative_returns[1004:]
# Out:
#                  SPY       VAW       VCR       VIS       IYR      VNQ     VDC  \
# Date
# 2017-12-28  0.464411  0.337205  0.459922  0.446031 -0.101095  0.10803  0.3404
#
#                  XLP       XLF       VHT      VGT       VDE
# Date
# 2017-12-28  0.341905  0.961619  0.543547  0.86854 -0.203097

# %%
c3_all_sectors_cumulative_returns_barchart
# Out:
# :Bars   [Date,Variable]   (value)

# %%
c3_all_sectors_cumulative_returns[750:]
# Out:
#                  SPY       VAW       VCR       VIS       IYR       VNQ  \
# Date
# 2019-12-27  0.433404  0.178562  0.474662  0.287821  0.044313 -0.084413
#
#                  VDC      XLP       XLF       VHT       VGT       VDE
# Date
# 2019-12-27  0.204493  0.21869  0.308805  0.500701  0.500701 -0.233217

# %%
# Plot cumulative returns for first dip period. 

c1_all_sectors_cumulative_returns = (1 + c1_all_sectors_daily_returns).cumprod() - 1
c1_all_sectors_cumulative_returns

c1_all_sectors_cumulative_returns.tail()


# Plot cumulative returns for second dip period. 

c2_all_sectors_cumulative_returns = (1 + c2_all_sectors_daily_returns).cumprod() - 1
c2_all_sectors_cumulative_returns

c2_all_sectors_cumulative_returns.tail()



# Plot cumulative returns for third dip period. 

c3_all_sectors_cumulative_returns = (1 + c3_all_sectors_daily_returns).cumprod() - 1
c3_all_sectors_cumulative_returns

c3_all_sectors_cumulative_returns.tail()


# Plot cumulative returns for all three crashes. 

c123_all_sectors_cumulative_returns = pd.concat(
    [c1_all_sectors_cumulative_returns[874:],
    c2_all_sectors_cumulative_returns[1004:],
    c3_all_sectors_cumulative_returns[750:]], 
    axis="rows", 
    join="inner"
).reset_index()


c123_all_sectors_cumulative_returns
#c123_all_sectors_cumulative_returns
c123_all_sectors_cumulative_returns['Crash']=['Crash 1','Crash 2','Crash 3']
c123_all_sectors_cumulative_returns_table = c123_all_sectors_cumulative_returns.drop(columns='Date').set_index('Crash')
c123_all_sectors_cumulative_returns_table
# Out:
#               SPY       VAW       VCR       VIS       IYR       VNQ       VDC  \
# Crash
# Crash 1 -0.165319  0.001091 -0.041126 -0.095424 -0.687700 -0.301830  0.091747
# Crash 2  0.464411  0.337205  0.459922  0.446031 -0.101095  0.108030  0.340400
# Crash 3  0.433404  0.178562  0.474662  0.287821  0.044313 -0.084413  0.204493
#
#               XLP       XLF       VHT       VGT       VDE
# Crash
# Crash 1  0.079044 -0.576537 -0.081914  0.093628  0.045340
# Crash 2  0.341905  0.961619  0.543547  0.868540 -0.203097
# Crash 3  0.218690  0.308805  0.500701  0.500701 -0.233217

# %%
# All Crashes - Top Performers based on cumulative returns
c123_cumulative_return_sunburst_csv = pd.read_csv(
    Path("c123_cumulative_return_sunburst_csv.csv"),
    infer_datetime_format=True,
    parse_dates=True
)
c123_cumulative_return_sunburst_csv
# Out:
#      Crash Ticker  Cumulative Return
# 0  Crash 1    VGT           0.093628
# 1  Crash 1    VDC           0.091747
# 2  Crash 1    XLP           0.079044
# 3  Crash 2    XLF           0.961619
# 4  Crash 2    VGT           0.868540
# 5  Crash 2    VHT           0.543547
# 6  Crash 3    VHT           0.500701
# 7  Crash 3    VGT           0.500701
# 8  Crash 3    VCR           0.474662

# %%
# Render sunburst plot to demonstrate the top performing sector ETFs across all three market4 crashes. 
c123_cumulative_return_sunburst_csv_fig = px.sunburst(
    c123_cumulative_return_sunburst_csv, 
    path=['Crash', 'Ticker'], 
    values='Cumulative Return',
    title='Sectors Which Outperformed S&P500 in Cumulative Returns Across Three Market Crashes',
    height=800,
    width=1000,
)

c123_cumulative_return_sunburst_csv_fig.show()

# %% [markdown]
# ##### Analysis of above chart goes here

# %%
import hvplot.pandas
import plotly.express as px

# %%
combined_full_date_range_daily_returns.plot(figsize=(20,10))

# %%
combined_first_dip_daily_returns.plot(figsize=(20,10))

# %%
combined_second_dip_daily_returns.plot(figsize=(20,10))

# %%
combined_third_dip_daily_returns.plot(figsize=(20,10))

# %%
combined_full_date_range_daily_returns.hvplot()

# %% [markdown]
# ### FULL TIMEFRAME - SPY vs VAW

# %%
#list(combined_full_date_range_daily_returns.columns)

spy_v_vaw_full_df = pd.concat([f_spy_ss_csv, f_vaw_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
spy_v_vaw_full_df.sort_index(inplace=True)

# Set column names
spy_v_vaw_full_df.columns = ['SPY', 'VAW']

# Display a few rows
#spy_v_vaw_full_df.head()

# Use the `pct_change` function to calculate daily returns
spy_v_vaw_full_daily_returns = spy_v_vaw_full_df.pct_change().dropna()
spy_v_vaw_full_daily_returns.head()


spy_v_vaw_full_daily_returns.head()

# %%
spy_v_vaw_full_daily_returns.hvplot()

# %%
spy_v_vaw_full_daily_returns.plot(figsize=(20,10))

# %%
spy_v_vaw_full_chart = spy_v_vaw_full_daily_returns.hvplot.scatter(
    'Date',
    ['SPY', 'VAW'],
    title='SPY v VAW - Daily Returns - Full Range',
    xlabel='X',
    ylabel='Y',
    groupby='Date',
    height=500, 
    width=800, 
    rot=90,
)
spy_v_vaw_full_chart

# %%
#list(combined_full_date_range_daily_returns.columns)

spy_v_vaw_first_dip_df = pd.concat([c1_spy_ss_csv, c1_vaw_ss_csv], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
spy_v_vaw_first_dip_df.sort_index(inplace=True)

# Set column names
spy_v_vaw_first_dip_df.columns = ['SPY', 'VAW']

# Display a few rows
#spy_v_vaw_first_dip_df.head()

# Use the `pct_change` function to calculate daily returns
spy_v_vaw_first_dip_daily_returns = spy_v_vaw_first_dip_df.pct_change().dropna()
spy_v_vaw_first_dip_daily_returns.head()


#spy_v_vaw_first_dip_daily_returns.head()

# %%
spy_v_vaw_first_dip_daily_returns.hvplot()

# %%
spy_vaw_first_dip_std = spy_v_vaw_first_dip_daily_returns.std()
spy_vaw_first_dip_std.head()

# %%
spy_vaw_first_dip_std.hvplot.bar(
    title='Oct 2007 to Mar 2009 - Std Dev - SPY vs. VAW')

# %%
spy_vaw_first_dip_correlation = spy_v_vaw_first_dip_daily_returns.corr()
spy_vaw_first_dip_correlation

# %%
spy_v_vaw_first_dip_daily_returns.describe()

# %% [markdown]
# ##### The first dip, from Oct 2007 to Mar 2009, shows both SPY and VAW as losing on a daily basis, with VAW losing slightly more on average. VAW's std is slightly higher, indicating greater volatility. VAW is closely-correlated with SPY, at 0.879139 correlation.

# %%
# Calculate sharpe ratio
import numpy as np
spy_v_vaw_first_dip_sharpe_ratios = (spy_v_vaw_first_dip_daily_returns.mean() * 252) / (spy_vaw_first_dip_std * np.sqrt(252))
spy_v_vaw_first_dip_sharpe_ratios.head()

# %%
spy_v_vaw_first_dip_sharpe_ratios.hvplot.bar(
    title='Oct 2007 to Mar 2009 - Sharpe Ratios - SPY vs. VAW')

# %% [markdown]
# ##### Analysis of above bar chart goes here

# %%
# Use the `std` function and multiply by the square root of the number of trading days in a year to get annualized volatility
volatility = daily_returns.std() * np.sqrt(252)
volatility.sort_values(inplace=True)
volatility

# Drop the five stocks with the highest volatility in daily returns
daily_returns.drop(columns=['MU', 'WDC', 'JNJ', 'FANG', 'WRK'], inplace=True)
daily_returns.head()

# Set weights for corresponding risk profile of stocks, use the `dot` function to multiply each weight by the corresponding stock daily return
# BK, LUV, NKE, SBUX, T
weights = [0.15, 0.05, 0.10, 0.2, 0.50]
portfolio_returns = daily_returns.dot(weights)
portfolio_returns.head()

# Use the `cumprod` function to calculate cumulative returns
cumulative_returns = (1 + portfolio_returns).cumprod()
cumulative_returns.head()

# Plot the returns of the portfolio in terms of money
initial_investment = 10000
cumulative_profit = initial_investment * cumulative_returns
cumulative_profit.plot()
